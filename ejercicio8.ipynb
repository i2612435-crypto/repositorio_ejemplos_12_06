# %% [markdown]
# <a href="https://colab.research.google.com/github/i2612435-crypto/repositorio_ejemplos_12_06/blob/main/ejercicio8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IDL2 - Ejercicio 8: Área de terreno triangular
# Estructura secuencial

print("=== EJERCICIO 8: ÁREA DE TERRENO ===")
base = 12
altura = 7
area = (base * altura) / 2

print(f"Base del terreno: {base} m")
print(f"Altura del terreno: {altura} m")
print(f"Área del terreno: {area} m²")
# Out:
# === EJERCICIO 8: ÁREA DE TERRENO ===
# Base del terreno: 12 m
# Altura del terreno: 7 m
# Área del terreno: 42.0 m²
