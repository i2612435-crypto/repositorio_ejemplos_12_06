# %% [markdown]
# <a href="https://colab.research.google.com/github/i2612435-crypto/repositorio_ejemplos_12_06/blob/main/ejercicio24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercicio 24: Encontrar máximo y mínimo
numeros = [45, 22, 89, 3, 67, 12, 34, 56]
maximo = max(numeros)
minimo = min(numeros)
print(f"Máximo: {maximo}, Mínimo: {minimo}")
# Out:
# Máximo: 89, Mínimo: 3
