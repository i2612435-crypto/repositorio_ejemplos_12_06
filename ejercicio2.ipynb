# %% [markdown]
# <a href="https://colab.research.google.com/github/i2612435-crypto/repositorio_ejemplos_12_06/blob/main/ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IDL2 - Ejercicio 2: Promedio de 4 exámenes
# Estructura secuencial

print("=== EJERCICIO 2: PROMEDIO DE EXÁMENES ===")
notas = [15, 16, 14, 17]
promedio = sum(notas) / len(notas)

print(f"Notas: {notas}")
print(f"Promedio: {promedio:.2f}")
# Out:
# === EJERCICIO 2: PROMEDIO DE EXÁMENES ===
# Notas: [15, 16, 14, 17]
# Promedio: 15.50
