# %% [markdown]
# <a href="https://colab.research.google.com/github/i2612435-crypto/repositorio_ejemplos_12_06/blob/main/ejercicio6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IDL2 - Ejercicio 6: Tiempo vivido
# Estructura secuencial

print("=== EJERCICIO 6: TIEMPO VIVIDO ===")
edad = 25
meses = edad * 12
semanas = edad * 52.1429
dias = edad * 365
horas = dias * 24

print(f"Edad: {edad} años")
print(f"Meses vividos: {meses}")
print(f"Semanas vividas: {int(semanas)}")
print(f"Días vividos: {dias}")
print(f"Horas vividas: {horas}")
# Out:
# === EJERCICIO 6: TIEMPO VIVIDO ===
# Edad: 25 años
# Meses vividos: 300
# Semanas vividas: 1303
# Días vividos: 9125
# Horas vividas: 219000
